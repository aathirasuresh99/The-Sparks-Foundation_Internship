# %% [markdown]
# ## The Sparks Foundation

# %% [markdown]
# # Data Science and Business Analytics- GRIP MARCH 2022

# %% [markdown]
# ## Author- Aathira Suresh

# %% [markdown]
# ## TASK 4- Exploratory Data Analysis- Terrorism

# %% [markdown]
# In this task, it is required to do the following
#
# 1. Perform Exploratory data Analysis on the 'Global Terrorism' dataset
#
# 2. Identify hot zones of terrorism
#
# 3. Identify security issues and derive insights

# %% [markdown]
# **Importing necessary dataset**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
from warnings import filterwarnings
filterwarnings('ignore')
plt.rcParams['figure.figsize']=15,7

# %% [markdown]
# **DATASET :** https://bit.ly/2TK5Xn5

# %% [markdown]
# **Reading the Dataset**

# %%
df1=pd.read_csv('globalterrorismdb_0718dist.csv', encoding='latin1')
df=df1.copy()
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# ### Performing Exploratory Data Analysis

# %% [markdown]
# **Describing the numerical features**

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# **Describing the categorical features**

# %%
df.describe(include='object')
# Out:
#                    approxdate resolution country_txt  \
# count                    9239       2220      181691
# unique                   2244       1859         205
# top     September 18-24, 2016   8/4/1998        Iraq
# freq                      101         18       24636
#
#                         region_txt provstate     city  \
# count                       181691    181270   181257
# unique                          12      2855    36674
# top     Middle East & North Africa   Baghdad  Unknown
# freq                         50474      7645     9775
#
#                                                 location  \
# count                                              55495
# unique                                             44109
# top     The attack took place in Baghdad, Baghdad, Iraq.
# freq                                                 142
#
#                                                   summary  \
# count                                              115562
# unique                                             112492
# top     09/00/2016: Sometime between September 18, 201...
# freq                                                  100
#
#                    alternative_txt    attacktype1_txt  ...   divert  \
# count                        29011             181691  ...      324
# unique                           5                  9  ...      143
# top     Insurgency/Guerilla Action  Bombing/Explosion  ...  Unknown
# freq                         23410              88255  ...       27
#
#        kidhijcountry ransomnote hostkidoutcome_txt  \
# count           3305        514              10991
# unique           217        387                  7
# top         Colombia          0            Unknown
# freq             687         36               3606
#
#                                                  addnotes  \
# count                                               28289
# unique                                              15429
# top     Casualty numbers for this incident conflict ac...
# freq                                                 1607
#
#                                                    scite1  \
# count                                              115500
# unique                                              83988
# top     Committee on Government Operations United Stat...
# freq                                                  205
#
#                                                    scite2  \
# count                                               76933
# unique                                              62263
# top     Christopher Hewitt, "Political Violence and Te...
# freq                                                  134
#
#                                                    scite3  \
# count                                               43516
# unique                                              36090
# top     Christopher Hewitt, "Political Violence and Te...
# freq                                                  139
#
#                         dbsource  \
# count                     181691
# unique                        26
# top     START Primary Collection
# freq                       78002
#
#                                                   related
# count                                               25038
# unique                                              14306
# top     201612010023, 201612010024, 201612010025, 2016...
# freq                                                   80
#
# [4 rows x 58 columns]

# %% [markdown]
# **Missing values Treatment**

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
plt.rcParams["figure.figsize"]=[15,5]
sns.heatmap(df.isnull(), cbar = False)
plt.show()

# %%
missing_values = df.isnull().sum()
total = df.isnull().sum().sort_values(ascending=False)
percent = ((df.isnull().sum()/df.shape[0])*100)
percent = percent.sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data['Type'] = df[missing_data.index].dtypes
missing_data
# Out:
#                    Total    Percent     Type
# gsubname3         181671  99.988992   object
# weapsubtype4_txt  181621  99.961473   object
# weapsubtype4      181621  99.961473  float64
# weaptype4         181618  99.959822  float64
# weaptype4_txt     181618  99.959822   object
# ...                  ...        ...      ...
# suicide                0   0.000000    int64
# success                0   0.000000    int64
# crit3                  0   0.000000    int64
# property               0   0.000000    int64
# eventid                0   0.000000    int64
#
# [135 rows x 3 columns]

# %%
nan_data=missing_data[missing_data['Percent']>60]
nan_data
# Out:
#                    Total    Percent     Type
# gsubname3         181671  99.988992   object
# weapsubtype4_txt  181621  99.961473   object
# weapsubtype4      181621  99.961473  float64
# weaptype4         181618  99.959822  float64
# weaptype4_txt     181618  99.959822   object
# ...                  ...        ...      ...
# motive            131130  72.171984   object
# location          126196  69.456385   object
# propcomment       123732  68.100236   object
# propextent        117626  64.739585  float64
# propextent_txt    117626  64.739585   object
#
# [75 rows x 3 columns]

# %%
nan_data.index
# Out:
# Index(['gsubname3', 'weapsubtype4_txt', 'weapsubtype4', 'weaptype4',
#        'weaptype4_txt', 'claimmode3', 'claimmode3_txt', 'gsubname2', 'claim3',
#        'guncertain3', 'gname3', 'divert', 'attacktype3', 'attacktype3_txt',
#        'ransomnote', 'ransompaidus', 'ransomamtus', 'claimmode2',
#        'claimmode2_txt', 'ransompaid', 'corp3', 'targsubtype3',
#        'targsubtype3_txt', 'natlty3_txt', 'natlty3', 'target3', 'targtype3',
#        'targtype3_txt', 'ransomamt', 'weapsubtype3_txt', 'weapsubtype3',
#        'weaptype3_txt', 'weaptype3', 'claim2', 'guncertain2', 'gname2',
#        'resolution', 'kidhijcountry', 'nhours', 'compclaim', 'gsubname',
#        'attacktype2', 'attacktype2_txt', 'ndays', 'approxdate', 'corp2',
#        'nreleased', 'targsubtype2', 'targsubtype2_txt', 'natlty2',
#        'natlty2_txt', 'hostkidoutcome_txt', 'hostkidoutcome', 'target2',
#        'targtype2_txt', 'targtype2', 'weapsubtype2', 'weapsubtype2_txt',
#        'weaptype2', 'weaptype2_txt', 'nhostkidus', 'nhostkid', 'claimmode_txt',
#        'claimmode', 'related', 'addnotes', 'alternative', 'alternative_txt',
#        'propvalue', 'scite3', 'motive', 'location', 'propcomment',
#        'propextent', 'propextent_txt'],
#       dtype='object')

# %%
df.drop(['gsubname3', 'weapsubtype4_txt', 'weapsubtype4', 'weaptype4',
       'weaptype4_txt', 'claimmode3', 'claimmode3_txt', 'gsubname2', 'claim3',
       'guncertain3', 'gname3', 'divert', 'attacktype3', 'attacktype3_txt',
       'ransomnote', 'ransompaidus', 'ransomamtus', 'claimmode2',
       'claimmode2_txt', 'ransompaid', 'corp3', 'targsubtype3',
       'targsubtype3_txt', 'natlty3_txt', 'natlty3', 'target3', 'targtype3',
       'targtype3_txt', 'ransomamt', 'weapsubtype3_txt', 'weapsubtype3',
       'weaptype3_txt', 'weaptype3', 'claim2', 'guncertain2', 'gname2',
       'resolution', 'kidhijcountry', 'nhours', 'compclaim', 'gsubname',
       'attacktype2', 'attacktype2_txt', 'ndays', 'approxdate', 'corp2',
       'nreleased', 'targsubtype2', 'targsubtype2_txt', 'natlty2',
       'natlty2_txt', 'hostkidoutcome_txt', 'hostkidoutcome', 'target2',
       'targtype2_txt', 'targtype2', 'weapsubtype2', 'weapsubtype2_txt',
       'weaptype2', 'weaptype2_txt', 'nhostkidus', 'nhostkid', 'claimmode_txt',
       'claimmode', 'related', 'addnotes', 'alternative', 'alternative_txt',
       'propvalue', 'scite3', 'motive', 'location', 'propcomment',
       'propextent', 'propextent_txt'], axis=1, inplace=True)

# %%
missing_data[missing_data['Percent']<60]
# Out:
#                    Total    Percent     Type
# scite2            104758  57.657231   object
# ransom            104310  57.410659  float64
# nperps             71115  39.140629  float64
# nperpcap           69489  38.245703  float64
# nwoundte           69143  38.055270  float64
# weapdetail         67670  37.244553   object
# nkillter           66958  36.852678  float64
# scite1             66191  36.430533   object
# summary            66129  36.396409   object
# claimed            66120  36.391456  float64
# nwoundus           64702  35.611010  float64
# nkillus            64446  35.470111  float64
# corp1              42550  23.418882   object
# weapsubtype1       20768  11.430396  float64
# weapsubtype1_txt   20768  11.430396   object
# nwound             16311   8.977330  float64
# targsubtype1       10373   5.709144  float64
# targsubtype1_txt   10373   5.709144   object
# nkill              10313   5.676120  float64
# longitude           4557   2.508104  float64
# latitude            4556   2.507554  float64
# natlty1             1559   0.858050  float64
# natlty1_txt         1559   0.858050   object
# target1              636   0.350045   object
# city                 434   0.238867   object
# provstate            421   0.231712   object
# guncertain1          380   0.209146  float64
# ishostkid            178   0.097969  float64
# specificity            6   0.003302  float64
# doubtterr              1   0.000550  float64
# multiple               1   0.000550  float64
# crit1                  0   0.000000    int64
# iyear                  0   0.000000    int64
# iday                   0   0.000000    int64
# imonth                 0   0.000000    int64
# targtype1_txt          0   0.000000   object
# gname                  0   0.000000   object
# individual             0   0.000000    int64
# dbsource               0   0.000000   object
# country                0   0.000000    int64
# INT_LOG                0   0.000000    int64
# INT_IDEO               0   0.000000    int64
# INT_MISC               0   0.000000    int64
# INT_ANY                0   0.000000    int64
# extended               0   0.000000    int64
# region_txt             0   0.000000   object
# country_txt            0   0.000000   object
# region                 0   0.000000    int64
# crit2                  0   0.000000    int64
# targtype1              0   0.000000    int64
# weaptype1              0   0.000000    int64
# weaptype1_txt          0   0.000000   object
# attacktype1_txt        0   0.000000   object
# attacktype1            0   0.000000    int64
# vicinity               0   0.000000    int64
# suicide                0   0.000000    int64
# success                0   0.000000    int64
# crit3                  0   0.000000    int64
# property               0   0.000000    int64
# eventid                0   0.000000    int64

# %%
df_num=df.select_dtypes(include=np.number)
df_cat=df.select_dtypes(include=object)

# %%
for i in df_num.columns:
    df[i].fillna(df[i].median(), inplace=True)
for i in df_cat.columns:
    df[i].fillna(df[i].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# eventid             0
# iyear               0
# imonth              0
# iday                0
# extended            0
# country             0
# country_txt         0
# region              0
# region_txt          0
# provstate           0
# city                0
# latitude            0
# longitude           0
# specificity         0
# vicinity            0
# summary             0
# crit1               0
# crit2               0
# crit3               0
# doubtterr           0
# multiple            0
# success             0
# suicide             0
# attacktype1         0
# attacktype1_txt     0
# targtype1           0
# targtype1_txt       0
# targsubtype1        0
# targsubtype1_txt    0
# corp1               0
# target1             0
# natlty1             0
# natlty1_txt         0
# gname               0
# guncertain1         0
# individual          0
# nperps              0
# nperpcap            0
# claimed             0
# weaptype1           0
# weaptype1_txt       0
# weapsubtype1        0
# weapsubtype1_txt    0
# weapdetail          0
# nkill               0
# nkillus             0
# nkillter            0
# nwound              0
# nwoundus            0
# nwoundte            0
# property            0
# ishostkid           0
# ransom              0
# scite1              0
# scite2              0
# dbsource            0
# INT_LOG             0
# INT_IDEO            0
# INT_MISC            0
# INT_ANY             0
# dtype: int64

# %%
plt.rcParams["figure.figsize"]=[15,5]
sns.heatmap(df.isnull(), cbar = False)
plt.show()

# %% [markdown]
# ### Identifying hot zones of terrorism

# %% [markdown]
# **A table depicting the frequencies of the two features ie., region_txt, attacktype1_txt**

# %%
pd.crosstab(df['region_txt'],df['attacktype1_txt'])
# Out:
# attacktype1_txt              Armed Assault  Assassination  Bombing/Explosion  \
# region_txt
# Australasia & Oceania                   51             36                 75
# Central America & Caribbean           4361           1254               3239
# Central Asia                           116            115                235
# East Asia                              117             55                330
# Eastern Europe                        1274            400               2766
# Middle East & North Africa            9273           4206              30908
# North America                          448            255               1534
# South America                         3875           2745               9039
# South Asia                           11404           4301              21246
# Southeast Asia                        4022           1369               4818
# Sub-Saharan Africa                    6004           1638               5557
# Western Europe                        1724           2938               8508
#
# attacktype1_txt              Facility/Infrastructure Attack  Hijacking  \
# region_txt
# Australasia & Oceania                                    71          3
# Central America & Caribbean                             403         26
# Central Asia                                             20          8
# East Asia                                               200         18
# Eastern Europe                                          260         26
# Middle East & North Africa                             1115        138
# North America                                           906         18
# South America                                           803         67
# South Asia                                             2189         93
# Southeast Asia                                          948         59
# Sub-Saharan Africa                                      810        136
# Western Europe                                         2631         67
#
# attacktype1_txt              Hostage Taking (Barricade Incident)  \
# region_txt
# Australasia & Oceania                                          6
# Central America & Caribbean                                  187
# Central Asia                                                   2
# East Asia                                                      3
# Eastern Europe                                                21
# Middle East & North Africa                                   100
# North America                                                 67
# South America                                                234
# South Asia                                                   120
# Southeast Asia                                                67
# Sub-Saharan Africa                                            95
# Western Europe                                                89
#
# attacktype1_txt              Hostage Taking (Kidnapping)  Unarmed Assault  \
# region_txt
# Australasia & Oceania                                 13               11
# Central America & Caribbean                          501               19
# Central Asia                                          45                5
# East Asia                                             14               42
# Eastern Europe                                       220               62
# Middle East & North Africa                          2666              177
# North America                                        123               73
# South America                                       1414               47
# South Asia                                          3277              323
# Southeast Asia                                       744               25
# Sub-Saharan Africa                                  1872               83
# Western Europe                                       269              148
#
# attacktype1_txt              Unknown
# region_txt
# Australasia & Oceania             16
# Central America & Caribbean      354
# Central Asia                      17
# East Asia                         23
# Eastern Europe                   115
# Middle East & North Africa      1891
# North America                     32
# South America                    754
# South Asia                      2021
# Southeast Asia                   433
# Sub-Saharan Africa              1355
# Western Europe                   265

# %% [markdown]
# **Inference :** From the above table we can see that Middle East and North Africa are highly affected due to Bombing and Explosion

# %% [markdown]
# **Forming a table that gives the number of attcks each year with respect to the region and plotting a graph for the same**

# %%
pd.crosstab(df['iyear'], df['region_txt']).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# **Inference :** The above graph depicts that South Asia, Middle East and North Africa are affected the most each year due to terrorism

# %% [markdown]
# **A countplot on top 10 countries affected due to terrorism**

# %%
ax = sns.countplot(df['country_txt'],order = df['country_txt'].value_counts().iloc[:10].index, palette='Greens');
ax.set_xlabel('Country', fontsize=12)
ax.set_ylabel('Count', fontsize=12)
ax.set_title('Terrorism in different country- top 10',fontsize=12);

# %% [markdown]
# **Inference :** From the above graph we can see that Iraq is the most affected due to terrorism followed by Pakistan, Afghanistan and India

# %% [markdown]
# **Forming a table on the highly affected country- Iraq**

# %%
iraq = df[df['country_txt']=='Iraq']
iraq.head()
# Out:
#            eventid  iyear  imonth  iday  extended  country country_txt  \
# 2854  197503010002   1975       3     1         0       95        Iraq
# 4385  197612150001   1976      12    15         0       95        Iraq
# 4393  197612180001   1976      12    18         1       95        Iraq
# 4402  197612240001   1976      12    24         0       95        Iraq
# 8688  197906150001   1979       6    15         0       95        Iraq
#
#       region                  region_txt provstate  ... property  ishostkid  \
# 2854      10  Middle East & North Africa   Nineveh  ...        0        1.0
# 4385      10  Middle East & North Africa   Baghdad  ...        1        0.0
# 4393      10  Middle East & North Africa   Unknown  ...        0        1.0
# 4402      10  Middle East & North Africa   Baghdad  ...        0        0.0
# 8688      10  Middle East & North Africa     Basra  ...        0        0.0
#
#       ransom                                             scite1  \
# 2854     1.0  Committee on Government Operations United Stat...
# 4385     0.0  Committee on Government Operations United Stat...
# 4393     1.0  Committee on Government Operations United Stat...
# 4402     0.0  Committee on Government Operations United Stat...
# 8688     0.0  Committee on Government Operations United Stat...
#
#                                                  scite2      dbsource  \
# 2854  Christopher Hewitt, "Political Violence and Te...  Hijacking DB
# 4385  Christopher Hewitt, "Political Violence and Te...          PGIS
# 4393  Christopher Hewitt, "Political Violence and Te...          PGIS
# 4402  Christopher Hewitt, "Political Violence and Te...          PGIS
# 8688  Christopher Hewitt, "Political Violence and Te...          PGIS
#
#       INT_LOG  INT_IDEO  INT_MISC  INT_ANY
# 2854       -9        -9         0       -9
# 4385       -9        -9         0       -9
# 4393        0         1         1        1
# 4402       -9        -9         1        1
# 8688       -9        -9         0       -9
#
# [5 rows x 60 columns]

# %% [markdown]
# **Line plot on the number of deaths in different years in Iraq due to terrorism**

# %%
sns.lineplot(x=iraq['iyear'],y=iraq['nkill']);

# %% [markdown]
# **Inference:** The above graph depicts that many number of people have died due to terrorism in Iraq between the years 1980 and 1985

# %% [markdown]
# **A pie chart on the top 10 cities being affected of terrorism**

# %%
cities=df['city'].value_counts()[1:10]
cities.plot(kind='pie',autopct="%1.1f%%",figsize=(12,12));

# %% [markdown]
# **Inference:** The above pie chart shows that the many number of cities affected of terrorism are not known whereas the Baghdad is ont of the topmost cities being affected due to terrorism.

# %% [markdown]
# ### Identifying security issues and deriving insights

# %% [markdown]
# **Frequency of terrorist gangs**

# %%
gangs=df['gname'].value_counts().reset_index()
gangs.rename(columns={"index":'Gang','gname':'Count'},inplace=True)
gangs
# Out:
#                                                   Gang  Count
# 0                                              Unknown  82782
# 1                                              Taliban   7478
# 2          Islamic State of Iraq and the Levant (ISIL)   5613
# 3                                    Shining Path (SL)   4555
# 4     Farabundo Marti National Liberation Front (FMLN)   3351
# ...                                                ...    ...
# 3532                                    Ansar Sarallah      1
# 3533                                    Sword of Islam      1
# 3534             Support of Ocalan-The Hawks of Thrace      1
# 3535                          Arab Revolutionary Front      1
# 3536                                            MANO-D      1
#
# [3537 rows x 2 columns]

# %% [markdown]
# **A bar plot on the top 10 gangs who are the reason for terrorism vs their count**

# %%
sns.barplot(x='Count', y='Gang', data=gangs[:10]);

# %% [markdown]
# **Inference:** From the above bar plot, we can see that the unknown set of terrorists are the reason for terrorism maximum number of times followed by Taliban and ISIL.

# %% [markdown]
# **A table showing the frequency of weapons used during the attack**

# %%
weapons=df['weaptype1_txt'].value_counts().reset_index()
weapons.rename(columns={"index":'Weapons','weaptype1_txt':'Count'},inplace=True)
weapons
# Out:
#                                               Weapons  Count
# 0                                          Explosives  92426
# 1                                            Firearms  58524
# 2                                             Unknown  15157
# 3                                          Incendiary  11135
# 4                                               Melee   3655
# 5                                            Chemical    321
# 6                                  Sabotage Equipment    141
# 7   Vehicle (not to include vehicle-borne explosiv...    136
# 8                                               Other    114
# 9                                          Biological     35
# 10                                       Fake Weapons     33
# 11                                       Radiological     14

# %% [markdown]
# **A bar plot on the top 5 weapons used vs their count**

# %%
sns.barplot(x='Count', y='Weapons', data=weapons.iloc[:5]);

# %% [markdown]
# **Inference:** From the above bar plot we can see that explosives are the mostly used weapons to attack different territories followed by Firearms

# %% [markdown]
# **A bar plot depicting the terrorists most favourite to least favourite target**

# %%
sns.barplot(x=df['targtype1_txt'].value_counts().values, y=df['targtype1_txt'].value_counts().index, palette='Reds');
plt.title("Terorrist's favorite target", fontsize=25);

# %% [markdown]
# **Inference:** From the above bar plot, we can see that the highly targetted section for the terrorists is Private Citezens and Property followed by Military and Police

# %% [markdown]
# **A table consisting of the recent 5 years with the sum of people killed and wonded in the corresponding years**

# %%
affects=df[['iyear','nkill','nwound']]
affects=affects.groupby('iyear')[['nkill','nwound']].sum()
affects=affects.tail()
affects.reset_index(inplace=True)
affects
# Out:
#    iyear    nkill   nwound
# 0   2013  22273.0  37688.0
# 1   2014  44490.0  41128.0
# 2   2015  38853.0  44043.0
# 3   2016  34871.0  40001.0
# 4   2017  26445.0  24927.0

# %% [markdown]
# **A bar plot on the number of people affected (killed and wonded) for the recent 5 years**

# %%
affects.plot(x='iyear',y=['nkill','nwound'],kind='bar',figsize=(18,4));
plt.title('Affected no.of people')
plt.ylabel('No.of People');

# %% [markdown]
# **Inference :** From the above bar plot we can see that the highest number of people wounded are in the year 2015 and the highest number of people who are killed are in the year 2014.

# %% [markdown]
# **Count plot on the frequency of terrorism in each year**

# %%
plt.figure(figsize = (15,7))
ax = sns.countplot(df['iyear'], palette= 'Blues');
plt.xticks(rotation = 90)
ax.set_xlabel('Year',fontsize=15)
ax.set_ylabel('Count', fontsize=15)
ax.set_title('Terrorism per Year',fontsize=15);

# %% [markdown]
# **Inference:** From the above plot we can see that the maximum terrorism took place in the year 2014 and minimum terrorism took place in 1971

# %% [markdown]
# ### Conclusion

# %% [markdown]
# 1. Keep an invigilation record on the areas which are considered the top terrorist targetted countries, regions and cities.
# 2. Aim at decreasing the number of terrorist attacks by introducing high security systems in the borders.
# 3. Reduce the export of weapons which are manufactured within the country.
# 4. Increase medical facilities in the borders to avoid death.
